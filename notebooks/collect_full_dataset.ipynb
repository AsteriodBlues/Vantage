# %% [markdown]
# # Full Dataset Collection (2018-2024)
#
# Collect all race data across 7 years. This will take 30-60 minutes on first run.

# %%
import sys
sys.path.append('../src')

from data_collection import F1DataCollector
import time

print("F1 Data Collection - 2018 to 2024")
print("="*60)
# Out:
# 2025-11-14 18:30:37,710 - INFO - FastF1 cache enabled at: /Users/ritwik/Projects/Vantage/notebooks/../data/cache
# F1 Data Collection - 2018 to 2024
# ============================================================

# %% [markdown]
# ## Initialize Collector

# %%
collector = F1DataCollector(start_year=2018, end_year=2024)

print("\nThis collection will:")
print("- Collect data from 2018-2024 (7 years)")
print("- Process ~150-160 races")
print("- Save intermediate results after each year")
print("- Take 30-60 minutes on first run")
print("- Be much faster on subsequent runs (cached)")
print("\nStarting collection...\n")
# Out:
# 2025-11-14 18:30:39,290 - INFO - Initialized collector for years 2018-2024
# This collection will:
# - Collect data from 2018-2024 (7 years)
# - Process ~150-160 races
# - Save intermediate results after each year
# - Take 30-60 minutes on first run
# - Be much faster on subsequent runs (cached)
#
# Starting collection...

# %% [markdown]
# ## Run Full Collection
#
# **Important Notes:**
# - Watch for any error messages
# - Intermediate files are saved after each year
# - If interrupted, you can restart and it will use cached data
# - Monitor memory usage - this creates a large dataset

# %%
start_time = time.time()

# THE BIG RUN
race_data = collector.collect_race_data(save_intermediate=True)

elapsed_time = time.time() - start_time
minutes = int(elapsed_time // 60)
seconds = int(elapsed_time % 60)

print(f"\n\nCollection completed in {minutes}m {seconds}s")
# Out:
# 2025-11-14 18:30:41,628 - INFO -
# ======================================================================
# 2025-11-14 18:30:41,629 - INFO - Starting full data collection: 2018-2024
# 2025-11-14 18:30:41,630 - INFO - ======================================================================
#
# 2025-11-14 18:30:41,630 - INFO -
# ============================================================
# 2025-11-14 18:30:41,631 - INFO - Processing 2018 season
# 2025-11-14 18:30:41,631 - INFO - ============================================================
# 2025-11-14 18:30:41,631 - INFO - Starting collection for 2018 season
# 2018 Season:   0%|          | 0/21 [00:00<?, ?it/s]core           INFO 	Loading data for Australian Grand Prix - Race [v3.6.1]
# 2025-11-14 18:30:42,054 - INFO - Loading data for Australian Grand Prix - Race [v3.6.1]
# req            INFO 	Using cached data for session_info
# 2025-11-14 18:30:42,056 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-11-14 18:30:42,057 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-11-14 18:30:42,777 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# 2025-11-14 18:30:42,778 - INFO - Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# 2025-11-14 18:30:42,779 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-11-14 18:30:42,783 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-11-14 18:30:42,785 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-11-14 18:30:42,785 - INFO - Processing timing data...
# core        WARNING 	Fixed incorrect tyre stint information for driver '28'
# 2025-11-14 18:30:42,915 - WARNING - Fixed incorrect tyre stint information for driver '28'
# req            INFO 	Using cached data for car_data
# 2025-11-14 18:30:43,363 - INFO - Using cached data for car_data
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 18:30:43,364 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:30:43,365 - INFO - Fetching position data...
# 2025-11-14 18:30:43,958 - DEBUG - Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car position data is unavailable!
# 2025-11-14 18:30:44,376 - WARNING - Car position data is unavailable!
# req            INFO 	Using cached data for weather_data
# 2025-11-14 18:30:44,577 - INFO - Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# 2025-11-14 18:30:44,578 - INFO - Using cached data for race_control_messages
# core        WARNING 	Driver 5 completed the race distance 00:00.123000 before the recorded end of the session.
# 2025-11-14 18:30:44,580 - WARNING - Driver 5 completed the race distance 00:00.123000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['5', '44', '7', '3', '14', '33', '27', '77', '2', '55', '11', '31', '16', '18', '28', '8', '20', '10', '9', '35']
# 2025-11-14 18:30:44,603 - INFO - Finished loading data for 20 drivers: ['5', '44', '7', '3', '14', '33', '27', '77', '2', '55', '11', '31', '16', '18', '28', '8', '20', '10', '9', '35']
# 2025-11-14 18:30:44,604 - INFO - Collected 2018 Round 1: Australian Grand Prix
# 2018 Season:   5%|▍         | 1/21 [00:03<01:01,  3.06s/it]core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.6.1]
# 2025-11-14 18:30:45,117 - INFO - Loading data for Bahrain Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:30:45,118 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:30:45,118 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:45,776 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:30:45,777 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:30:45,778 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:46,397 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:30:46,609 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:30:46,610 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:47,206 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:30:47,208 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:30:47,209 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:47,801 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:30:47,802 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:30:47,803 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:48,432 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:30:48,433 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:30:48,434 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:30:49,479 - INFO - Parsing timing data...
# _api        WARNING 	Failed to align laps for drivers: ['3', '33']
# 2025-11-14 18:30:49,742 - WARNING - Failed to align laps for drivers: ['3', '33']
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:49,761 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 18:30:49,762 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 18:30:49,762 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:50,369 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 18:30:50,369 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 18:30:50,829 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 18:30:50,830 - INFO - Fetching car data...
# 2025-11-14 18:30:51,500 - DEBUG - Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car telemetry data is unavailable!
# 2025-11-14 18:30:51,844 - WARNING - Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 18:30:51,845 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:30:51,847 - INFO - Fetching position data...
# 2025-11-14 18:30:52,422 - DEBUG - Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car position data is unavailable!
# 2025-11-14 18:30:52,831 - WARNING - Car position data is unavailable!
# core        WARNING 	Failed to determine `Session.t0_date`!
# 2025-11-14 18:30:52,832 - WARNING - Failed to determine `Session.t0_date`!
# logger      WARNING 	Failed to load telemetry data!
# 2025-11-14 18:30:52,833 - WARNING - Failed to load telemetry data!
# 2025-11-14 18:30:52,833 - DEBUG - Traceback for failure in telemetry data
# Traceback (most recent call last):
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/core.py", line 2644, in _load_telemetry
#     = self._laps['LapStartTime'] + self.t0_date
#       ~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/pandas/core/ops/common.py", line 76, in new_method
#     return method(self, other)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/pandas/core/arraylike.py", line 186, in __add__
#     return self._arith_method(other, operator.add)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/pandas/core/series.py", line 6154, in _arith_method
#     return base.IndexOpsMixin._arith_method(self, other, op)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/pandas/core/base.py", line 1391, in _arith_method
#     result = ops.arithmetic_op(lvalues, rvalues, op)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/pandas/core/ops/array_ops.py", line 273, in arithmetic_op
#     res_values = op(left, right)
# TypeError: unsupported operand type(s) for +: 'TimedeltaArray' and 'NoneType'
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:30:52,838 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:30:52,838 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:53,453 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:30:53,454 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:30:53,455 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:54,072 - INFO - Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['5', '77', '44', '10', '20', '27', '14', '2', '9', '31', '55', '16', '8', '18', '35', '11', '28', '7', '33', '3']
# 2025-11-14 18:30:54,148 - INFO - Finished loading data for 20 drivers: ['5', '77', '44', '10', '20', '27', '14', '2', '9', '31', '55', '16', '8', '18', '35', '11', '28', '7', '33', '3']
# 2025-11-14 18:30:54,149 - INFO - Collected 2018 Round 2: Bahrain Grand Prix
# 2018 Season:  10%|▉         | 2/21 [00:12<02:10,  6.87s/it]core           INFO 	Loading data for Chinese Grand Prix - Race [v3.6.1]
# 2025-11-14 18:30:54,668 - INFO - Loading data for Chinese Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:30:54,670 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:30:54,670 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:55,295 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:30:55,296 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:30:55,297 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:55,918 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:30:56,217 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:30:56,218 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:56,758 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:30:56,760 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:30:56,760 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:57,315 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:30:57,317 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:30:57,317 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:57,871 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:30:57,873 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:30:57,873 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:30:58,911 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:59,194 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 18:30:59,194 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 18:30:59,195 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:30:59,851 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 18:30:59,852 - INFO - Processing timing data...
# core        WARNING 	Fixed incorrect tyre stint information for driver '3'
# 2025-11-14 18:30:59,857 - WARNING - Fixed incorrect tyre stint information for driver '3'
# core        WARNING 	Fixed incorrect tyre stint information for driver '33'
# 2025-11-14 18:30:59,892 - WARNING - Fixed incorrect tyre stint information for driver '33'
# core        WARNING 	Fixed incorrect tyre stint information for driver '27'
# 2025-11-14 18:30:59,901 - WARNING - Fixed incorrect tyre stint information for driver '27'
# core        WARNING 	Fixed incorrect tyre stint information for driver '55'
# 2025-11-14 18:30:59,923 - WARNING - Fixed incorrect tyre stint information for driver '55'
# core        WARNING 	Fixed incorrect tyre stint information for driver '31'
# 2025-11-14 18:30:59,938 - WARNING - Fixed incorrect tyre stint information for driver '31'
# core        WARNING 	Fixed incorrect tyre stint information for driver '11'
# 2025-11-14 18:30:59,946 - WARNING - Fixed incorrect tyre stint information for driver '11'
# core        WARNING 	Fixed incorrect tyre stint information for driver '35'
# 2025-11-14 18:30:59,966 - WARNING - Fixed incorrect tyre stint information for driver '35'
# core        WARNING 	Fixed incorrect tyre stint information for driver '8'
# 2025-11-14 18:30:59,983 - WARNING - Fixed incorrect tyre stint information for driver '8'
# core        WARNING 	Fixed incorrect tyre stint information for driver '10'
# 2025-11-14 18:30:59,990 - WARNING - Fixed incorrect tyre stint information for driver '10'
# core        WARNING 	Fixed incorrect tyre stint information for driver '28'
# 2025-11-14 18:31:00,005 - WARNING - Fixed incorrect tyre stint information for driver '28'
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 18:31:00,367 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 18:31:00,368 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 18:31:01,510 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:02,877 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 18:31:02,878 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:31:02,878 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 18:31:04,156 - INFO - Parsing position data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:05,136 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:31:05,474 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:31:05,475 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:06,058 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:31:06,061 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:31:06,061 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:06,669 - INFO - Data has been written to cache!
# core        WARNING 	Driver 3 completed the race distance 00:00.025000 before the recorded end of the session.
# 2025-11-14 18:31:06,673 - WARNING - Driver 3 completed the race distance 00:00.025000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['3', '77', '7', '44', '33', '27', '14', '5', '55', '20', '31', '11', '2', '18', '35', '9', '8', '10', '16', '28']
# 2025-11-14 18:31:06,693 - INFO - Finished loading data for 20 drivers: ['3', '77', '7', '44', '33', '27', '14', '5', '55', '20', '31', '11', '2', '18', '35', '9', '8', '10', '16', '28']
# 2025-11-14 18:31:06,694 - INFO - Collected 2018 Round 3: Chinese Grand Prix
# 2018 Season:  14%|█▍        | 3/21 [00:25<02:50,  9.47s/it]core           INFO 	Loading data for Azerbaijan Grand Prix - Race [v3.6.1]
# 2025-11-14 18:31:07,214 - INFO - Loading data for Azerbaijan Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:31:07,215 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:31:07,216 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:07,787 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:31:07,788 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:31:07,789 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:08,404 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:31:08,674 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:31:08,675 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:09,320 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:31:09,322 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:31:09,323 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:09,871 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:31:09,873 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:31:09,873 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:10,450 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:31:10,452 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:31:10,453 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:31:11,827 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:12,052 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 18:31:12,052 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 18:31:12,053 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:12,771 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 18:31:12,772 - INFO - Processing timing data...
# core        WARNING 	Fixed incorrect tyre stint information for driver '7'
# 2025-11-14 18:31:12,790 - WARNING - Fixed incorrect tyre stint information for driver '7'
# core        WARNING 	Fixed incorrect tyre stint information for driver '14'
# 2025-11-14 18:31:12,839 - WARNING - Fixed incorrect tyre stint information for driver '14'
# core        WARNING 	Fixed incorrect tyre stint information for driver '28'
# 2025-11-14 18:31:12,868 - WARNING - Fixed incorrect tyre stint information for driver '28'
# core        WARNING 	Fixed incorrect tyre stint information for driver '9'
# 2025-11-14 18:31:12,879 - WARNING - Fixed incorrect tyre stint information for driver '9'
# core        WARNING 	Fixed incorrect tyre stint information for driver '20'
# 2025-11-14 18:31:12,898 - WARNING - Fixed incorrect tyre stint information for driver '20'
# core        WARNING 	Driver 55: Lap timing integrity check failed for 1 lap(s)
# 2025-11-14 18:31:12,998 - WARNING - Driver 55: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 18:31:13,312 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 18:31:13,313 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 18:31:15,215 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:16,625 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 18:31:16,626 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:31:16,626 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 18:31:18,054 - INFO - Parsing position data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:19,064 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:31:19,402 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:31:19,403 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:20,085 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:31:20,087 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:31:20,088 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:20,698 - INFO - Data has been written to cache!
# core        WARNING 	Driver 44 completed the race distance 00:00.110000 before the recorded end of the session.
# 2025-11-14 18:31:20,702 - WARNING - Driver 44 completed the race distance 00:00.110000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['44', '7', '11', '5', '55', '16', '14', '18', '2', '28', '9', '10', '20', '77', '8', '33', '3', '27', '31', '35']
# 2025-11-14 18:31:20,777 - INFO - Finished loading data for 20 drivers: ['44', '7', '11', '5', '55', '16', '14', '18', '2', '28', '9', '10', '20', '77', '8', '33', '3', '27', '31', '35']
# 2025-11-14 18:31:20,778 - INFO - Collected 2018 Round 4: Azerbaijan Grand Prix
# 2018 Season:  19%|█▉        | 4/21 [00:39<03:11, 11.29s/it]core           INFO 	Loading data for Spanish Grand Prix - Race [v3.6.1]
# 2025-11-14 18:31:21,296 - INFO - Loading data for Spanish Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:31:21,297 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:31:21,298 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:21,874 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:31:21,875 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:31:21,876 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:22,542 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:31:23,059 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:31:23,060 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:23,659 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:31:23,661 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:31:23,662 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:24,278 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:31:24,279 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:31:24,280 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:24,892 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:31:24,894 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:31:24,894 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:31:26,526 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:26,757 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 18:31:26,758 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 18:31:26,758 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:27,420 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 18:31:27,421 - INFO - Processing timing data...
# core        WARNING 	Fixed incorrect tyre stint information for driver '28'
# 2025-11-14 18:31:27,540 - WARNING - Fixed incorrect tyre stint information for driver '28'
# core        WARNING 	Fixed incorrect tyre stint information for driver '35'
# 2025-11-14 18:31:27,560 - WARNING - Fixed incorrect tyre stint information for driver '35'
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 18:31:27,951 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 18:31:27,952 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 18:31:29,790 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:31,110 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 18:31:31,111 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:31:31,111 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 18:31:33,900 - INFO - Parsing position data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:34,840 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:31:35,160 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:31:35,160 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:35,731 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:31:35,733 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:31:35,733 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:36,362 - INFO - Data has been written to cache!
# core        WARNING 	Driver 44 completed the race distance 00:00.017000 before the recorded end of the session.
# 2025-11-14 18:31:36,365 - WARNING - Driver 44 completed the race distance 00:00.017000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '5', '3', '20', '55', '14', '11', '16', '18', '28', '9', '35', '2', '31', '7', '8', '10', '27']
# 2025-11-14 18:31:36,391 - INFO - Finished loading data for 20 drivers: ['44', '77', '33', '5', '3', '20', '55', '14', '11', '16', '18', '28', '9', '35', '2', '31', '7', '8', '10', '27']
# 2025-11-14 18:31:36,392 - INFO - Collected 2018 Round 5: Spanish Grand Prix
# 2018 Season:  24%|██▍       | 5/21 [00:54<03:25, 12.85s/it]core           INFO 	Loading data for Monaco Grand Prix - Race [v3.6.1]
# 2025-11-14 18:31:36,915 - INFO - Loading data for Monaco Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:31:36,916 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:31:36,917 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:37,481 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:31:37,482 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:31:37,482 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:38,104 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:31:38,720 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:31:38,721 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:39,326 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:31:39,328 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:31:39,329 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:39,950 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:31:39,951 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:31:39,952 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:40,559 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:31:40,561 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:31:40,561 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:31:42,362 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:42,687 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 18:31:42,688 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 18:31:42,688 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:43,395 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 18:31:43,396 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 18:31:43,962 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 18:31:43,963 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 18:31:45,769 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:47,189 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 18:31:47,189 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:31:47,189 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 18:31:48,844 - INFO - Parsing position data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:49,871 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:31:50,214 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:31:50,214 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:50,785 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:31:50,787 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:31:50,787 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:51,369 - INFO - Data has been written to cache!
# core        WARNING 	Driver 3 completed the race distance 00:00.040000 before the recorded end of the session.
# 2025-11-14 18:31:51,373 - WARNING - Driver 3 completed the race distance 00:00.040000 before the recorded end of the session.
# core           INFO 	Finished loading data for 20 drivers: ['3', '5', '44', '7', '77', '31', '10', '27', '33', '55', '9', '11', '20', '2', '8', '35', '18', '16', '28', '14']
# 2025-11-14 18:31:51,409 - INFO - Finished loading data for 20 drivers: ['3', '5', '44', '7', '77', '31', '10', '27', '33', '55', '9', '11', '20', '2', '8', '35', '18', '16', '28', '14']
# 2025-11-14 18:31:51,410 - INFO - Collected 2018 Round 6: Monaco Grand Prix
# 2018 Season:  29%|██▊       | 6/21 [01:09<03:23, 13.59s/it]core           INFO 	Loading data for Canadian Grand Prix - Race [v3.6.1]
# 2025-11-14 18:31:51,923 - INFO - Loading data for Canadian Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:31:51,925 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:31:51,925 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:52,540 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:31:52,541 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:31:52,542 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:53,264 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:31:53,559 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:31:53,560 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:54,178 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:31:54,180 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:31:54,181 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:54,793 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:31:54,794 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:31:54,795 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:31:55,405 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:31:55,407 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:31:55,408 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:31:56,618 - INFO - Parsing timing data...
# _api        WARNING 	Driver  5: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# 2025-11-14 18:31:56,625 - WARNING - Driver  5: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# _api        WARNING 	Driver  5: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# 2025-11-14 18:31:56,627 - WARNING - Driver  5: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# _api        WARNING 	Driver 77: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# 2025-11-14 18:31:56,632 - WARNING - Driver 77: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# _api        WARNING 	Driver 77: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# 2025-11-14 18:31:56,633 - WARNING - Driver 77: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# _api        WARNING 	Driver 33: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# 2025-11-14 18:31:56,644 - WARNING - Driver 33: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# _api        WARNING 	Driver 33: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# 2025-11-14 18:31:56,645 - WARNING - Driver 33: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# _api        WARNING 	Driver 44: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# 2025-11-14 18:31:56,656 - WARNING - Driver 44: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# _api        WARNING 	Driver 44: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# 2025-11-14 18:31:56,656 - WARNING - Driver 44: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# _api        WARNING 	Driver  7: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# 2025-11-14 18:31:56,670 - WARNING - Driver  7: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# _api        WARNING 	Driver  7: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# 2025-11-14 18:31:56,671 - WARNING - Driver  7: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# _api        WARNING 	Driver  3: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# 2025-11-14 18:31:56,682 - WARNING - Driver  3: Ignoring late data for a previously processed lap.The data may contain errors (previous: 69; current 70)
# _api        WARNING 	Driver  3: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# 2025-11-14 18:31:56,683 - WARNING - Driver  3: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 70)
# _api        WARNING 	Driver 27: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# 2025-11-14 18:31:56,694 - WARNING - Driver 27: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# _api        WARNING 	Driver 27: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# 2025-11-14 18:31:56,694 - WARNING - Driver 27: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# _api        WARNING 	Driver 31: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# 2025-11-14 18:31:56,708 - WARNING - Driver 31: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# _api        WARNING 	Driver 31: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# 2025-11-14 18:31:56,709 - WARNING - Driver 31: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# _api        WARNING 	Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# 2025-11-14 18:31:56,724 - WARNING - Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# _api        WARNING 	Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# 2025-11-14 18:31:56,725 - WARNING - Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# _api        WARNING 	Driver 11: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# 2025-11-14 18:31:56,737 - WARNING - Driver 11: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# _api        WARNING 	Driver 11: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# 2025-11-14 18:31:56,738 - WARNING - Driver 11: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# _api        WARNING 	Driver 20: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# 2025-11-14 18:31:56,749 - WARNING - Driver 20: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# _api        WARNING 	Driver 20: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# 2025-11-14 18:31:56,749 - WARNING - Driver 20: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# _api        WARNING 	Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# 2025-11-14 18:31:56,760 - WARNING - Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# _api        WARNING 	Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# 2025-11-14 18:31:56,761 - WARNING - Driver 16: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 69)
# _api        WARNING 	Driver  2: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 68)
# 2025-11-14 18:31:56,778 - WARNING - Driver  2: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 68)
# _api        WARNING 	Driver  2: Ignoring late data for a previously processed lap.The data may contain errors (previous: 66; current 68)
# 2025-11-14 18:31:56,779 - WARNING - Driver  2: Ignoring late data for a previously processed lap.The data may contain errors (previous: 66; current 68)
# _api        WARNING 	Driver 35: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 68)
# 2025-11-14 18:31:56,790 - WARNING - Driver 35: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 68)
# _api        WARNING 	Driver 35: Ignoring late data for a previously processed lap.The data may contain errors (previous: 66; current 68)
# 2025-11-14 18:31:56,790 - WARNING - Driver 35: Ignoring late data for a previously processed lap.The data may contain errors (previous: 66; current 68)
# _api        WARNING 	Driver  9: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 68)
# 2025-11-14 18:31:56,801 - WARNING - Driver  9: Ignoring late data for a previously processed lap.The data may contain errors (previous: 67; current 68)
# _api        WARNING 	Driver  9: Ignoring late data for a previously processed lap.The data may contain errors (previous: 66; current 68)
# 2025-11-14 18:31:56,801 - WARNING - Driver  9: Ignoring late data for a previously processed lap.The data may contain errors (previous: 66; current 68)
# _api        WARNING 	Driver 10: Ignoring late data for a previously processed lap.The data may contain errors (previous: 68; current 69)
# ...
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	No cached data found for season_schedule. Loading data...
# 2025-11-14 18:40:07,894 - INFO - No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# 2025-11-14 18:40:07,894 - INFO - Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# 2025-11-14 18:40:08,140 - WARNING - Failed to load schedule from F1 API backend!
# 2025-11-14 18:40:08,140 - DEBUG - Traceback for failure in F1 API schedule
# Traceback (most recent call last):
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/events.py", line 659, in _get_schedule_from_f1_timing
#     response = fastf1._api.season_schedule(f'/static/{year}/')
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/_api.py", line 1678, in season_schedule
#     response = fetch_page(path, 'index')
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/_api.py", line 1752, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# 2025-11-14 18:40:08,386 - WARNING - Failed to load schedule from Ergast API backend!
# 2025-11-14 18:40:08,387 - DEBUG - Traceback for failure in Ergast API Schedule
# Traceback (most recent call last):
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/events.py", line 746, in _get_schedule_from_ergast
#     season = fastf1.ergast.fetch_season(year)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/ergast/legacy.py", line 29, in fetch_season
#     Cache.requests_get(url, headers=_headers))
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# 2025-11-14 18:40:08,390 - ERROR - Failed to get schedule for 2023: Failed to load any schedule data.
# 2025-11-14 18:40:08,390 - ERROR - Failed to collect data for 2023
# 2025-11-14 18:40:08,390 - INFO -
# ============================================================
# 2025-11-14 18:40:08,391 - INFO - Processing 2024 season
# 2025-11-14 18:40:08,391 - INFO - ============================================================
# 2025-11-14 18:40:08,391 - INFO - Starting collection for 2024 season
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# 2025-11-14 18:40:08,634 - WARNING - Failed to load schedule from FastF1 backend!
# 2025-11-14 18:40:08,635 - DEBUG - Traceback for failure in FastF1 schedule
# Traceback (most recent call last):
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/events.py", line 599, in _get_schedule_ff1
#     response = Cache.requests_get(
#         _SCHEDULE_BASE_URL + f"schedule_{year}.json",
#         headers=_HEADERS
#     )
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	No cached data found for season_schedule. Loading data...
# 2025-11-14 18:40:08,637 - INFO - No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# 2025-11-14 18:40:08,638 - INFO - Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# 2025-11-14 18:40:08,889 - WARNING - Failed to load schedule from F1 API backend!
# 2025-11-14 18:40:08,890 - DEBUG - Traceback for failure in F1 API schedule
# Traceback (most recent call last):
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/events.py", line 659, in _get_schedule_from_f1_timing
#     response = fastf1._api.season_schedule(f'/static/{year}/')
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 479, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/_api.py", line 1678, in season_schedule
#     response = fetch_page(path, 'index')
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/_api.py", line 1752, in fetch_page
#     r = Cache.requests_get(base_url + path + pages[name], headers=headers)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# 2025-11-14 18:40:09,132 - WARNING - Failed to load schedule from Ergast API backend!
# 2025-11-14 18:40:09,133 - DEBUG - Traceback for failure in Ergast API Schedule
# Traceback (most recent call last):
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/logger.py", line 151, in __wrapped
#     return func(*args, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/events.py", line 746, in _get_schedule_from_ergast
#     season = fastf1.ergast.fetch_season(year)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/ergast/legacy.py", line 29, in fetch_season
#     Cache.requests_get(url, headers=_headers))
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 303, in requests_get
#     return cls._cached_request('GET', url, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 347, in _cached_request
#     response = func(url, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 127, in get
#     return self.request('GET', url, params=params, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 183, in request
#     return super().request(method, url, *args, headers=headers, **kwargs)  # type: ignore
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 230, in send
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/requests_cache/session.py", line 254, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 134, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "/Users/ritwik/Projects/Vantage/venv/lib/python3.13/site-packages/fastf1/req.py", line 104, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: any API: 500 calls/h
# 2025-11-14 18:40:09,136 - ERROR - Failed to get schedule for 2024: Failed to load any schedule data.
# 2025-11-14 18:40:09,136 - ERROR - Failed to collect data for 2024
# 2025-11-14 18:40:09,138 - INFO -
# ======================================================================
# 2025-11-14 18:40:09,139 - INFO - Data Validation
# 2025-11-14 18:40:09,139 - INFO - ======================================================================
# 2025-11-14 18:40:09,142 - INFO - Average records per year: 390 (expected ~440)
# 2025-11-14 18:40:09,143 - INFO -
# ======================================================================
# 2025-11-14 18:40:09,143 - INFO - Collection Complete!
# 2025-11-14 18:40:09,143 - INFO - ======================================================================
# 2025-11-14 18:40:09,143 - INFO - Years collected: [2018, 2019]
# 2025-11-14 18:40:09,144 - INFO - Total races: 39
# 2025-11-14 18:40:09,144 - INFO - Total records: 780
# 2025-11-14 18:40:09,144 - INFO - Unique drivers: 26
# 2025-11-14 18:40:09,144 - INFO - Unique circuits: 21
# 2025-11-14 18:40:09,145 - WARNING - Failed years: [2020, 2021, 2022, 2023, 2024]
# 2025-11-14 18:40:09,145 - INFO - ======================================================================
# Collection completed in 9m 27s

# %% [markdown]
# ## Quick Data Check

# %%
if race_data is not None:
    print("\nQuick validation:")
    print(f"Total records: {len(race_data):,}")
    print(f"Shape: {race_data.shape}")
    print(f"Years: {sorted(race_data['year'].unique())}")
    print(f"Races: {race_data['race_name'].nunique()}")
    print(f"Drivers: {race_data['DriverNumber'].nunique()}")
    print(f"Circuits: {race_data['circuit'].nunique()}")
    print(f"\nMemory usage: {race_data.memory_usage(deep=True).sum() / (1024*1024):.2f} MB")
else:
    print("\n ERROR: No data collected!")
# Out:
# Quick validation:
# Total records: 780
# Shape: (780, 27)
# Years: [np.int64(2018), np.int64(2019)]
# Races: 21
# Drivers: 26
# Circuits: 21
#
# Memory usage: 0.75 MB

# %% [markdown]
# ## Save Complete Dataset

# %%
if race_data is not None:
    print("Saving complete dataset...\n")
    collector.save_data(race_data, 'race_data', create_backup=True)
    print("\n SUCCESS! Dataset saved.")
else:
    print("ERROR: Cannot save - no data collected")
# Out:
# 2025-11-14 18:43:24,214 - INFO - Saved 780 records:
# 2025-11-14 18:43:24,214 - INFO -   CSV: /Users/ritwik/Projects/Vantage/notebooks/../data/raw/race_data.csv (156.65 KB)
# 2025-11-14 18:43:24,214 - INFO -   Pickle: /Users/ritwik/Projects/Vantage/notebooks/../data/raw/race_data.pkl (197.23 KB)
# 2025-11-14 18:43:24,217 - INFO - Backup created in /Users/ritwik/Projects/Vantage/notebooks/../data/raw/backup
# Saving complete dataset...
#
#
#  SUCCESS! Dataset saved.

# %% [markdown]
# ## Collection Summary

# %%
if race_data is not None:
    print("="*70)
    print("COLLECTION COMPLETE")
    print("="*70)
    print(f"\nTime elapsed: {minutes}m {seconds}s")
    print(f"Total records: {len(race_data):,}")
    print(f"\nFiles saved:")
    print("  - data/raw/race_data.csv")
    print("  - data/raw/race_data.pkl")
    print("  - data/raw/backup/race_data.csv (backup)")
    print("  - data/raw/backup/race_data.pkl (backup)")
    print(f"\nIntermediate files (by year):")
    for year in sorted(race_data['year'].unique()):
        print(f"  - data/raw/races_{year}.csv")
    print("\nNext steps:")
    print("  1. Run data verification notebook")
    print("  2. Check data quality")
    print("  3. Begin exploratory analysis")
    print("="*70)
else:
    print("="*70)
    print("COLLECTION FAILED")
    print("="*70)
    print("Check error messages above for details.")
    print("="*70)
# Out:
# ======================================================================
# COLLECTION COMPLETE
# ======================================================================
#
# Time elapsed: 9m 27s
# Total records: 780
#
# Files saved:
#   - data/raw/race_data.csv
#   - data/raw/race_data.pkl
#   - data/raw/backup/race_data.csv (backup)
#   - data/raw/backup/race_data.pkl (backup)
#
# Intermediate files (by year):
#   - data/raw/races_2018.csv
#   - data/raw/races_2019.csv
#
# Next steps:
#   1. Run data verification notebook
#   2. Check data quality
#   3. Begin exploratory analysis
# ======================================================================
