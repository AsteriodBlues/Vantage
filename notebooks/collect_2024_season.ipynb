# %% [markdown]
# # 2024 Season Data Collection
#
# Full season collection test before running the complete 7-year data gathering.

# %%
import sys
sys.path.append('../src')

from data_collection import F1DataCollector
import pandas as pd
import time

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Initialize Collector

# %%
# Create collector instance
collector = F1DataCollector()

print("Starting 2024 season collection...")
print("This will take a few minutes on first run.")
print("Subsequent runs will be much faster due to caching.\n")
# Out:
# 2025-11-14 17:55:05,273 - INFO - Initialized collector for years 2018-2024
# Starting 2024 season collection...
# This will take a few minutes on first run.
# Subsequent runs will be much faster due to caching.

# %% [markdown]
# ## Collect 2024 Season

# %%
# Track collection time
start_time = time.time()

# Collect all 2024 races
data_2024 = collector.collect_season_data(2024, include_sprints=False)

# Calculate elapsed time
elapsed_time = time.time() - start_time
minutes = int(elapsed_time // 60)
seconds = int(elapsed_time % 60)

print(f"\nCollection completed in {minutes}m {seconds}s")
# Out:
# 2025-11-14 17:55:11,373 - INFO - Starting collection for 2024 season
# 2024 Season:   0%|          | 0/24 [00:00<?, ?it/s]core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.6.1]
# 2025-11-14 17:55:11,737 - INFO - Loading data for Bahrain Grand Prix - Race [v3.6.1]
# req            INFO 	Using cached data for session_info
# 2025-11-14 17:55:11,738 - INFO - Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# 2025-11-14 17:55:11,739 - INFO - Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# 2025-11-14 17:55:11,753 - INFO - Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# 2025-11-14 17:55:11,754 - INFO - Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# 2025-11-14 17:55:11,755 - INFO - Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# 2025-11-14 17:55:11,759 - INFO - Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# 2025-11-14 17:55:11,760 - INFO - Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# 2025-11-14 17:55:11,761 - INFO - Processing timing data...
# req            INFO 	Using cached data for car_data
# 2025-11-14 17:55:12,138 - INFO - Using cached data for car_data
# req            INFO 	Using cached data for position_data
# 2025-11-14 17:55:12,174 - INFO - Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# 2025-11-14 17:55:12,768 - INFO - Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# 2025-11-14 17:55:12,770 - INFO - Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']
# 2025-11-14 17:55:12,802 - INFO - Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']
# 2025-11-14 17:55:12,803 - INFO - Collected 2024 Round 1: Bahrain Grand Prix
# 2024 Season:   4%|▍         | 1/24 [00:01<00:36,  1.58s/it]core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.6.1]
# 2025-11-14 17:55:13,320 - INFO - Loading data for Saudi Arabian Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 17:55:13,321 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 17:55:13,322 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:13,891 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 17:55:13,892 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 17:55:13,893 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:14,596 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 17:55:15,212 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 17:55:15,212 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:15,824 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 17:55:15,825 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 17:55:15,826 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:16,430 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 17:55:16,430 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 17:55:16,431 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:17,042 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 17:55:17,044 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 17:55:17,044 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 17:55:18,804 - INFO - Parsing timing data...
# _api        WARNING 	Failed to align laps for drivers: ['10']
# 2025-11-14 17:55:19,208 - WARNING - Failed to align laps for drivers: ['10']
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:19,250 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 17:55:19,251 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 17:55:19,251 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:19,996 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 17:55:19,996 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 17:55:20,507 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 17:55:20,508 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 17:55:21,933 - INFO - Parsing car data...
# _api        WARNING 	Driver 55: Car data is incomplete!
# 2025-11-14 17:55:23,861 - WARNING - Driver 55: Car data is incomplete!
# _api        WARNING 	Driver 38: Car data is incomplete!
# 2025-11-14 17:55:23,869 - WARNING - Driver 38: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:23,892 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 17:55:23,893 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 17:55:23,894 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 17:55:25,709 - INFO - Parsing position data...
# _api        WARNING 	Driver 55: Position data is incomplete!
# 2025-11-14 17:55:27,600 - WARNING - Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 38: Position data is incomplete!
# 2025-11-14 17:55:27,606 - WARNING - Driver 38: Position data is incomplete!
# _api        WARNING 	Driver 241: Position data is incomplete!
# 2025-11-14 17:55:27,611 - WARNING - Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# 2025-11-14 17:55:27,616 - WARNING - Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# 2025-11-14 17:55:27,621 - WARNING - Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:27,735 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 17:55:28,304 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 17:55:28,305 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:28,931 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 17:55:28,932 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 17:55:28,933 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:29,513 - INFO - Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '81', '14', '63', '38', '4', '44', '27', '23', '20', '31', '2', '22', '3', '77', '24', '18', '10']
# 2025-11-14 17:55:29,548 - INFO - Finished loading data for 20 drivers: ['1', '11', '16', '81', '14', '63', '38', '4', '44', '27', '23', '20', '31', '2', '22', '3', '77', '24', '18', '10']
# 2025-11-14 17:55:29,549 - INFO - Collected 2024 Round 2: Saudi Arabian Grand Prix
# 2024 Season:   8%|▊         | 2/24 [00:18<03:51, 10.50s/it]core           INFO 	Loading data for Australian Grand Prix - Race [v3.6.1]
# 2025-11-14 17:55:30,067 - INFO - Loading data for Australian Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 17:55:30,068 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 17:55:30,069 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:30,626 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 17:55:30,627 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 17:55:30,627 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:31,183 - INFO - Data has been written to cache!
# 2025-11-14 17:55:31,383 - DEBUG - Failed to parse timestamp '-1:57:37.891' in Ergastresponse.
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 17:55:31,392 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 17:55:31,392 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:32,008 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 17:55:32,010 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 17:55:32,011 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:32,614 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 17:55:32,615 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 17:55:32,615 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:33,224 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 17:55:33,225 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 17:55:33,225 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 17:55:35,056 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:35,502 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 17:55:35,503 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 17:55:35,503 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:36,154 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 17:55:36,155 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 17:55:36,685 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 17:55:36,686 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 17:55:38,841 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:40,769 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 17:55:40,769 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 17:55:40,770 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 17:55:42,915 - INFO - Parsing position data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:44,837 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 17:55:45,387 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 17:55:45,387 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:45,967 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 17:55:45,968 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 17:55:45,968 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:46,543 - INFO - Data has been written to cache!
# core           INFO 	Finished loading data for 19 drivers: ['55', '16', '4', '81', '11', '18', '22', '14', '27', '20', '23', '3', '10', '77', '24', '31', '63', '44', '1']
# 2025-11-14 17:55:46,578 - INFO - Finished loading data for 19 drivers: ['55', '16', '4', '81', '11', '18', '22', '14', '27', '20', '23', '3', '10', '77', '24', '31', '63', '44', '1']
# 2025-11-14 17:55:46,579 - INFO - Collected 2024 Round 3: Australian Grand Prix
# 2024 Season:  12%|█▎        | 3/24 [00:35<04:43, 13.48s/it]core           INFO 	Loading data for Japanese Grand Prix - Race [v3.6.1]
# 2025-11-14 17:55:47,095 - INFO - Loading data for Japanese Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 17:55:47,096 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 17:55:47,096 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:47,664 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 17:55:47,664 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 17:55:47,665 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:48,283 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 17:55:48,489 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 17:55:48,490 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:49,095 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 17:55:49,097 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 17:55:49,098 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:49,710 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 17:55:49,711 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 17:55:49,712 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:50,321 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 17:55:50,322 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 17:55:50,322 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 17:55:52,380 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:52,827 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 17:55:52,828 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 17:55:52,829 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:53,451 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 17:55:53,452 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 17:55:53,967 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 17:55:53,967 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 17:55:56,032 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:55:58,471 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 17:55:58,472 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 17:55:58,472 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 17:56:00,699 - INFO - Parsing position data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:56:03,201 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 17:56:03,884 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 17:56:03,884 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:56:04,585 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 17:56:04,587 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 17:56:04,587 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:56:05,182 - INFO - Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '4', '14', '63', '81', '44', '22', '27', '18', '20', '77', '31', '10', '2', '24', '3', '23']
# 2025-11-14 17:56:05,208 - INFO - Finished loading data for 20 drivers: ['1', '11', '55', '16', '4', '14', '63', '81', '44', '22', '27', '18', '20', '77', '31', '10', '2', '24', '3', '23']
# 2025-11-14 17:56:05,209 - INFO - Collected 2024 Round 4: Japanese Grand Prix
# 2024 Season:  17%|█▋        | 4/24 [00:53<05:10, 15.51s/it]core           INFO 	Loading data for Chinese Grand Prix - Race [v3.6.1]
# 2025-11-14 17:56:05,723 - INFO - Loading data for Chinese Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 17:57:16,857 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:17,473 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 17:57:17,474 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 17:57:17,474 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:18,025 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 17:57:18,026 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 17:57:18,027 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 17:57:19,956 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:20,545 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 17:57:20,546 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 17:57:20,546 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:21,259 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 17:57:21,259 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 17:57:21,880 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 17:57:21,881 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 17:57:23,839 - INFO - Parsing car data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:25,353 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# 2025-11-14 17:57:25,353 - INFO - No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 17:57:25,354 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 17:57:26,850 - INFO - Parsing position data...
# _api        WARNING 	Driver 241: Position data is incomplete!
# 2025-11-14 17:57:28,347 - WARNING - Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# 2025-11-14 17:57:28,352 - WARNING - Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# 2025-11-14 17:57:28,357 - WARNING - Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:28,429 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 17:57:28,871 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 17:57:28,872 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 17:57:29,444 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 17:57:29,445 - INFO - No cached data found for race_control_messages. Loading data...
# ...
# 2025-11-14 18:01:40,234 - WARNING - Driver 17: Position data is incomplete!
# _api        WARNING 	Driver 19: Position data is incomplete!
# 2025-11-14 18:01:40,240 - WARNING - Driver 19: Position data is incomplete!
# _api        WARNING 	Driver 21: Position data is incomplete!
# 2025-11-14 18:01:40,245 - WARNING - Driver 21: Position data is incomplete!
# _api        WARNING 	Driver 25: Position data is incomplete!
# 2025-11-14 18:01:40,250 - WARNING - Driver 25: Position data is incomplete!
# _api        WARNING 	Driver 26: Position data is incomplete!
# 2025-11-14 18:01:40,255 - WARNING - Driver 26: Position data is incomplete!
# _api        WARNING 	Driver 28: Position data is incomplete!
# 2025-11-14 18:01:40,260 - WARNING - Driver 28: Position data is incomplete!
# _api        WARNING 	Driver 29: Position data is incomplete!
# 2025-11-14 18:01:40,265 - WARNING - Driver 29: Position data is incomplete!
# _api        WARNING 	Driver 30: Position data is incomplete!
# 2025-11-14 18:01:40,274 - WARNING - Driver 30: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# 2025-11-14 18:01:40,282 - WARNING - Driver 31: Position data is incomplete!
# _api        WARNING 	Driver 43: Position data is incomplete!
# 2025-11-14 18:01:40,289 - WARNING - Driver 43: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# 2025-11-14 18:01:40,294 - WARNING - Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# 2025-11-14 18:01:40,300 - WARNING - Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# 2025-11-14 18:01:40,305 - WARNING - Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# 2025-11-14 18:01:40,311 - WARNING - Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 81: Position data is incomplete!
# 2025-11-14 18:01:40,316 - WARNING - Driver 81: Position data is incomplete!
# _api        WARNING 	Driver 241: Position data is incomplete!
# 2025-11-14 18:01:40,322 - WARNING - Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# 2025-11-14 18:01:40,327 - WARNING - Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# 2025-11-14 18:01:40,332 - WARNING - Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:40,521 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:01:41,150 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:01:41,151 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:41,770 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:01:41,771 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:01:41,772 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:42,388 - INFO - Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '81', '63', '10', '55', '14', '24', '20', '4', '77', '44', '22', '30', '23', '27', '11', '18', '43', '31']
# 2025-11-14 18:01:42,444 - INFO - Finished loading data for 20 drivers: ['1', '16', '81', '63', '10', '55', '14', '24', '20', '4', '77', '44', '22', '30', '23', '27', '11', '18', '43', '31']
# 2025-11-14 18:01:42,446 - INFO - Collected 2024 Round 23: Qatar Grand Prix
# 2024 Season:  96%|█████████▌| 23/24 [06:31<00:19, 19.92s/it]core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.6.1]
# 2025-11-14 18:01:42,961 - INFO - Loading data for Abu Dhabi Grand Prix - Race [v3.6.1]
# req            INFO 	No cached data found for session_info. Loading data...
# 2025-11-14 18:01:42,962 - INFO - No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# 2025-11-14 18:01:42,963 - INFO - Fetching session info data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:43,510 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# 2025-11-14 18:01:43,511 - INFO - No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# 2025-11-14 18:01:43,512 - INFO - Fetching driver list...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:44,129 - INFO - Data has been written to cache!
# 2025-11-14 18:01:44,429 - DEBUG - Failed to parse timestamp '-1:58:03.658' in Ergastresponse.
# req            INFO 	No cached data found for session_status_data. Loading data...
# 2025-11-14 18:01:44,442 - INFO - No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# 2025-11-14 18:01:44,443 - INFO - Fetching session status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:44,743 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# 2025-11-14 18:01:44,745 - INFO - No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# 2025-11-14 18:01:44,746 - INFO - Fetching lap count data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:45,352 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# 2025-11-14 18:01:45,353 - INFO - No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# 2025-11-14 18:01:45,354 - INFO - Fetching track status data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:45,919 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# 2025-11-14 18:01:45,920 - INFO - No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# 2025-11-14 18:01:45,921 - INFO - Fetching timing data...
# _api           INFO 	Parsing timing data...
# 2025-11-14 18:01:47,171 - INFO - Parsing timing data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:47,676 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# 2025-11-14 18:01:47,677 - INFO - No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# 2025-11-14 18:01:47,677 - INFO - Fetching timing app data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:48,411 - INFO - Data has been written to cache!
# core           INFO 	Processing timing data...
# 2025-11-14 18:01:48,411 - INFO - Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# 2025-11-14 18:01:48,991 - INFO - No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# 2025-11-14 18:01:48,992 - INFO - Fetching car data...
# _api           INFO 	Parsing car data...
# 2025-11-14 18:01:50,783 - INFO - Parsing car data...
# _api        WARNING 	Driver  2: Car data is incomplete!
# 2025-11-14 18:01:52,788 - WARNING - Driver  2: Car data is incomplete!
# _api        WARNING 	Driver  3: Car data is incomplete!
# 2025-11-14 18:01:52,794 - WARNING - Driver  3: Car data is incomplete!
cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# 2025-11-14 18:01:52,962 - INFO - Fetching position data...
# _api           INFO 	Parsing position data...
# 2025-11-14 18:01:55,389 - INFO - Parsing position data...
# _api        WARNING 	Driver  2: Position data is incomplete!
# 2025-11-14 18:01:57,374 - WARNING - Driver  2: Position data is incomplete!
# _api        WARNING 	Driver  3: Position data is incomplete!
# 2025-11-14 18:01:57,379 - WARNING - Driver  3: Position data is incomplete!
# _api        WARNING 	Driver  5: Position data is incomplete!
# 2025-11-14 18:01:57,385 - WARNING - Driver  5: Position data is incomplete!
# _api        WARNING 	Driver  6: Position data is incomplete!
# 2025-11-14 18:01:57,390 - WARNING - Driver  6: Position data is incomplete!
# _api        WARNING 	Driver  7: Position data is incomplete!
# 2025-11-14 18:01:57,395 - WARNING - Driver  7: Position data is incomplete!
# _api        WARNING 	Driver  8: Position data is incomplete!
# 2025-11-14 18:01:57,400 - WARNING - Driver  8: Position data is incomplete!
# _api        WARNING 	Driver  9: Position data is incomplete!
# 2025-11-14 18:01:57,405 - WARNING - Driver  9: Position data is incomplete!
# _api        WARNING 	Driver 12: Position data is incomplete!
# 2025-11-14 18:01:57,412 - WARNING - Driver 12: Position data is incomplete!
# _api        WARNING 	Driver 15: Position data is incomplete!
# 2025-11-14 18:01:57,417 - WARNING - Driver 15: Position data is incomplete!
# _api        WARNING 	Driver 17: Position data is incomplete!
# 2025-11-14 18:01:57,422 - WARNING - Driver 17: Position data is incomplete!
# _api        WARNING 	Driver 19: Position data is incomplete!
# 2025-11-14 18:01:57,427 - WARNING - Driver 19: Position data is incomplete!
# _api        WARNING 	Driver 21: Position data is incomplete!
# 2025-11-14 18:01:57,432 - WARNING - Driver 21: Position data is incomplete!
# _api        WARNING 	Driver 25: Position data is incomplete!
# 2025-11-14 18:01:57,437 - WARNING - Driver 25: Position data is incomplete!
# _api        WARNING 	Driver 26: Position data is incomplete!
# 2025-11-14 18:01:57,441 - WARNING - Driver 26: Position data is incomplete!
# _api        WARNING 	Driver 28: Position data is incomplete!
# 2025-11-14 18:01:57,447 - WARNING - Driver 28: Position data is incomplete!
# _api        WARNING 	Driver 29: Position data is incomplete!
# 2025-11-14 18:01:57,451 - WARNING - Driver 29: Position data is incomplete!
# _api        WARNING 	Driver 30: Position data is incomplete!
# 2025-11-14 18:01:57,456 - WARNING - Driver 30: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# 2025-11-14 18:01:57,462 - WARNING - Driver 31: Position data is incomplete!
# _api        WARNING 	Driver 43: Position data is incomplete!
# 2025-11-14 18:01:57,467 - WARNING - Driver 43: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# 2025-11-14 18:01:57,472 - WARNING - Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# 2025-11-14 18:01:57,478 - WARNING - Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 61: Position data is incomplete!
# 2025-11-14 18:01:57,483 - WARNING - Driver 61: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# 2025-11-14 18:01:57,489 - WARNING - Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# 2025-11-14 18:01:57,494 - WARNING - Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 81: Position data is incomplete!
# 2025-11-14 18:01:57,504 - WARNING - Driver 81: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:57,684 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# 2025-11-14 18:01:58,317 - INFO - No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# 2025-11-14 18:01:58,318 - INFO - Fetching weather data...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:58,973 - INFO - Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# 2025-11-14 18:01:58,974 - INFO - No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# 2025-11-14 18:01:58,975 - INFO - Fetching race control messages...
# req            INFO 	Data has been written to cache!
# 2025-11-14 18:01:59,596 - INFO - Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '55', '16', '44', '63', '1', '10', '27', '14', '81', '23', '22', '24', '18', '61', '20', '30', '77', '43', '11']
# 2025-11-14 18:01:59,642 - INFO - Finished loading data for 20 drivers: ['4', '55', '16', '44', '63', '1', '10', '27', '14', '81', '23', '22', '24', '18', '61', '20', '30', '77', '43', '11']
# 2025-11-14 18:01:59,643 - INFO - Collected 2024 Round 24: Abu Dhabi Grand Prix
# 2024 Season: 100%|██████████| 24/24 [06:48<00:00, 17.02s/it]
# 2025-11-14 18:02:00,158 - INFO - Collected 479 driver results from 24 races in 2024
# Collection completed in 6m 48s

# %% [markdown]
# ## Examine the Results

# %%
# Basic info
print(f"Total records: {len(data_2024):,}")
print(f"Shape: {data_2024.shape}")
print(f"Memory usage: {data_2024.memory_usage(deep=True).sum() / 1024:.2f} KB")
# Out:
# Total records: 479
# Shape: (479, 27)
# Memory usage: 526.46 KB

# %%
# Check number of races
num_races = data_2024['race_name'].nunique()
num_drivers = data_2024['DriverNumber'].nunique()

print(f"\nRaces collected: {num_races}")
print(f"Unique drivers: {num_drivers}")
print(f"Average drivers per race: {len(data_2024) / num_races:.1f}")
# Out:
# Races collected: 24
# Unique drivers: 25
# Average drivers per race: 20.0

# %%
# List all races
print("\nRaces in 2024 season:")
races = data_2024[['round', 'race_name', 'circuit', 'date']].drop_duplicates().sort_values('round')
print(races.to_string(index=False))
# Out:
# Races in 2024 season:
#  round                 race_name           circuit       date
#      1        Bahrain Grand Prix            Sakhir 2024-03-02
#      2  Saudi Arabian Grand Prix            Jeddah 2024-03-09
#      3     Australian Grand Prix         Melbourne 2024-03-24
#      4       Japanese Grand Prix            Suzuka 2024-04-07
#      5        Chinese Grand Prix          Shanghai 2024-04-21
#      6          Miami Grand Prix             Miami 2024-05-05
#      7 Emilia Romagna Grand Prix             Imola 2024-05-19
#      8         Monaco Grand Prix            Monaco 2024-05-26
#      9       Canadian Grand Prix          Montréal 2024-06-09
#     10        Spanish Grand Prix         Barcelona 2024-06-23
#     11       Austrian Grand Prix         Spielberg 2024-06-30
#     12        British Grand Prix       Silverstone 2024-07-07
#     13      Hungarian Grand Prix          Budapest 2024-07-21
#     14        Belgian Grand Prix Spa-Francorchamps 2024-07-28
#     15          Dutch Grand Prix         Zandvoort 2024-08-25
#     16        Italian Grand Prix             Monza 2024-09-01
#     17     Azerbaijan Grand Prix              Baku 2024-09-15
#     18      Singapore Grand Prix        Marina Bay 2024-09-22
#     19  United States Grand Prix            Austin 2024-10-20
#     20    Mexico City Grand Prix       Mexico City 2024-10-27
#     21      São Paulo Grand Prix         São Paulo 2024-11-03
#     22      Las Vegas Grand Prix         Las Vegas 2024-11-23
#     23          Qatar Grand Prix            Lusail 2024-12-01
#     24      Abu Dhabi Grand Prix        Yas Island 2024-12-08

# %% [markdown]
# ## Data Quality Checks

# %%
# Check for missing values
key_columns = ['Position', 'GridPosition', 'FullName', 'TeamName', 'Points', 'Status']
print("Missing values in key columns:")
print(data_2024[key_columns].isnull().sum())
# Out:
# Missing values in key columns:
# Position        0
# GridPosition    0
# FullName        0
# TeamName        0
# Points          0
# Status          0
# dtype: int64

# %%
# DNF statistics
total_entries = len(data_2024)
finished = (data_2024['Status'] == 'Finished').sum()
dnf = total_entries - finished
dnf_rate = (dnf / total_entries) * 100

print(f"\nDNF Statistics:")
print(f"Total entries: {total_entries}")
print(f"Finished: {finished}")
print(f"DNFs: {dnf}")
print(f"DNF rate: {dnf_rate:.1f}%")
# Out:
# DNF Statistics:
# Total entries: 479
# Finished: 287
# DNFs: 192
# DNF rate: 40.1%

# %%
# Most common DNF reasons
dnf_data = data_2024[data_2024['Status'] != 'Finished']
print("\nTop DNF reasons:")
print(dnf_data['Status'].value_counts().head(10))
# Out:
# Top DNF reasons:
# Status
# Lapped           138
# Retired           49
# Did not start      3
# Disqualified       2
# Name: count, dtype: int64

# %% [markdown]
# ## Quick Analysis

# %%
# Debug: Check Position column data type and sample values
print("Position column data type:", data_2024['Position'].dtype)
print("\nUnique Position values:")
print(sorted(data_2024['Position'].unique()))
print("\nSample of first place finishes:")
print(data_2024[data_2024['Position'] == 1][['race_name', 'Position', 'FullName', 'TeamName']].head())
# Out:
# Position column data type: float64
#
# Unique Position values:
# [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0), np.float64(6.0), np.float64(7.0), np.float64(8.0), np.float64(9.0), np.float64(10.0), np.float64(11.0), np.float64(12.0), np.float64(13.0), np.float64(14.0), np.float64(15.0), np.float64(16.0), np.float64(17.0), np.float64(18.0), np.float64(19.0), np.float64(20.0)]
#
# Sample of first place finishes:
#                    race_name  Position        FullName         TeamName
# 0         Bahrain Grand Prix       1.0  Max Verstappen  Red Bull Racing
# 20  Saudi Arabian Grand Prix       1.0  Max Verstappen  Red Bull Racing
# 40     Australian Grand Prix       1.0    Carlos Sainz          Ferrari
# 59       Japanese Grand Prix       1.0  Max Verstappen  Red Bull Racing
# 79        Chinese Grand Prix       1.0  Max Verstappen  Red Bull Racing

# %%
# Race winners
winners = data_2024[data_2024['Position'] == 1][['race_name', 'FullName', 'TeamName']]
print("\n2024 Race Winners:")
print(winners.to_string(index=False))
# Out:
# 2024 Race Winners:
#                 race_name        FullName        TeamName
#        Bahrain Grand Prix  Max Verstappen Red Bull Racing
#  Saudi Arabian Grand Prix  Max Verstappen Red Bull Racing
#     Australian Grand Prix    Carlos Sainz         Ferrari
#       Japanese Grand Prix  Max Verstappen Red Bull Racing
#        Chinese Grand Prix  Max Verstappen Red Bull Racing
#          Miami Grand Prix    Lando Norris         McLaren
# Emilia Romagna Grand Prix  Max Verstappen Red Bull Racing
#         Monaco Grand Prix Charles Leclerc         Ferrari
#       Canadian Grand Prix  Max Verstappen Red Bull Racing
#        Spanish Grand Prix  Max Verstappen Red Bull Racing
#       Austrian Grand Prix  George Russell        Mercedes
#        British Grand Prix  Lewis Hamilton        Mercedes
#      Hungarian Grand Prix   Oscar Piastri         McLaren
#        Belgian Grand Prix  Lewis Hamilton        Mercedes
#          Dutch Grand Prix    Lando Norris         McLaren
#        Italian Grand Prix Charles Leclerc         Ferrari
#     Azerbaijan Grand Prix   Oscar Piastri         McLaren
#      Singapore Grand Prix    Lando Norris         McLaren
#  United States Grand Prix Charles Leclerc         Ferrari
#    Mexico City Grand Prix    Carlos Sainz         Ferrari
#      São Paulo Grand Prix  Max Verstappen Red Bull Racing
#      Las Vegas Grand Prix  George Russell        Mercedes
#          Qatar Grand Prix  Max Verstappen Red Bull Racing
#      Abu Dhabi Grand Prix    Lando Norris         McLaren

# %%
# Driver wins count
win_counts = winners['FullName'].value_counts()
print("\nWins by driver:")
print(win_counts)
# Out:
# Wins by driver:
# FullName
# Max Verstappen     9
# Lando Norris       4
# Charles Leclerc    3
# Carlos Sainz       2
# George Russell     2
# Lewis Hamilton     2
# Oscar Piastri      2
# Name: count, dtype: int64

# %%
# Pole to win conversion
pole_winners = data_2024[
    (data_2024['Position'] == 1) & (data_2024['GridPosition'] == 1)
]
pole_win_rate = (len(pole_winners) / num_races) * 100

print(f"\nPole position to win conversion:")
print(f"Pole winners: {len(pole_winners)} / {num_races}")
print(f"Conversion rate: {pole_win_rate:.1f}%")
# Out:
# Pole position to win conversion:
# Pole winners: 11 / 24
# Conversion rate: 45.8%

# %% [markdown]
# ## Save the Data

# %%
# Save to CSV
collector.save_data(data_2024, 'races_2024.csv')

print("\nData saved successfully!")
# Out:
# 2025-11-14 18:12:19,648 - INFO - Saved 479 records to /Users/ritwik/Projects/Vantage/notebooks/../data/raw/races_2024.csv
# 2025-11-14 18:12:19,649 - INFO - File size: 153.52 KB
# 2025-11-14 18:12:19,649 - INFO - File size: 153.52 KB
# Data saved successfully!

# %% [markdown]
# ## Summary

# %%
print("=" * 70)
print("2024 Season Collection Summary")
print("=" * 70)
print(f"\n✓ Collection time: {minutes}m {seconds}s")
print(f"✓ Races collected: {num_races}")
print(f"✓ Total records: {len(data_2024):,}")
print(f"✓ Data quality: {(1 - dnf_rate/100) * 100:.1f}% finish rate")
print(f"✓ File saved: data/raw/races_2024.csv")
print(f"\nReady for full 2018-2024 collection!")
print(f"Estimated time for 7 years: ~{(elapsed_time * 7 / 60):.0f} minutes")
print("=" * 70)
# Out:
# ======================================================================
# 2024 Season Collection Summary
# ======================================================================
#
# ✓ Collection time: 6m 48s
# ✓ Races collected: 24
# ✓ Total records: 479
# ✓ Data quality: 59.9% finish rate
# ✓ File saved: data/raw/races_2024.csv
#
# Ready for full 2018-2024 collection!
# Estimated time for 7 years: ~48 minutes
# ======================================================================
